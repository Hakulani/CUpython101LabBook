# %% [markdown]
# 04-01: ผังงานปฏิทรรศน์วันเกิด 💡
# จงเขียนโปรแกรมที่ทำงานตามผังงานข้างล่างนี้
#
# ข้อมูลนำเข้า
# จำนวนจริงหนึ่งจำนวน
# ข้อมูลส่งออก
# ตามที่แสดงในผังงาน
#
#
# ![04-01.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ทำเงื่อนไขเป็น not  โดยต้องทำข้างนอกก่อน 1ครั้ง
#
#
# ![Not.JPG](data:image/jpeg;base64,...)

# %%
p=float(input())
k=1
t=1
t=t*(365-(k-1))/365
while (1-t<p):
    k+=1
    t=t*(365-(k-1))/365
print(k)
# Out:
# 0.7
# 30

# %% [markdown]
# 04-02 ฝังงานการแบ่งส่วน
#
# ![04-02.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ข้อมูลนำเข้า
# หนึ่งบรรทัดประกอบด้วยรายการของจำนวนเต็มคั่นด้วยช่องว่าง
# ใช้คำสั่ง d = [int(e) for e in input().split()]
#
# 9 2 7 1 6 8 4 5
# ข้อมูลส่งออก
# ตามที่แสดงในผังงาน   [2, 1, 4, 5, 6, 8, 7, 9]

# %%
d = [int(e) for e in input().split()]
p = d[-1]
i=-1;j=0
n=len(d)
while j<n-1:
    if d[j]<=p:
        i+=1
        d[i],d[j]=d[j],d[i]
    j+=1
d[i+1],d[-1]=d[-1],d[i+1]
print(d)
# Out:
# 9 2 7 1 6 8 4 5
# [2, 1, 4, 5, 6, 8, 7, 9]

# %% [markdown]
# 04-03 ค่าเฉลี่ย</br>
# จงเขียนโปรแกรมหาค่าเฉลี่ยของชุดข้อมูลที่รับจากแป้นพิมพ์</br>
# ข้อมูลนำเข้า
# จำนวนจริงบรรทัดละจำนวน บรรทัดสุดท้ายเป็นตัวอักษร q</br>
# ข้อมูลส่งออก
# ค่าเฉลี่ยของข้อมูลที่รับเข้ามา โดยแสดงเลขหลังจุดทศนิยม 2 ตำแหน่ง
# ถ้าไม่มีข้อมูลเลย ให้แสดง No Data

# %% [markdown]
# เขียนแบบป้องกัน error ช่วง conver str>float

# %%
n=0
x=0
sum=0
x=input()
while x!='q':
    if '0'<=x<='9':
        sum+=float(x)
        n+=1
        x=input()
        while x!='q' and 'a'<=x<='z' :
            x=input()

if n==0:
    print('No Data')  
else :
    avg=sum/n
    print("{:.2f}".format(avg))
    #print(round(avg,2))
# Out:
# 4
# 5
# a
# c
# q
# 4.50

# %% [markdown]
# แบบ while True  , break6

# %%
n=0
x=0
sum=0
x=input()
while True:
    x=input()
    if x=='q':
        break
    sum+=float(x)
    n+=1
if n ==0:
    print('No Data') 
else :
    avg=sum/n
    print("{:.2f}".format(avg))
    #print(round(avg,2))
# Out:
# 10
# 41.5
# q
# 25.75

# %% [markdown]
# แบบ X!='q' แต่อย่าลืม รับ inputใหม่ ก่อนวน loop

# %%
n=0
x=0
sum=0
x=input()
while x!='q':
    sum+=float(x)
    n+=1
    x=input()
if n==0:
    print('No Data')  
else :
    avg=sum/n
    print("{:.2f}".format(avg))  
    #print(round(avg,2))
# Out:
# 3
# 4
# q
# 3.50

# %% [markdown]
# 04-04
# การประมาณค่าของ log10 a ด้วย bisection (แบบที่ 1) 💡
# เราสามารถหาค่าประมาณของ sqr a ได้ด้วยวิธี bisection ดังนี้
# 1. ให้ L = 0, U = a
# 2. เริ่มให้คำตอบอยูในช่วง [L, U]
# 3. x = จุดกึ่งกลางของช่วง
# 4. ทำข้างล่างนี้ซ้ำ ถ้า x^2 ยังมีค่าไม่ใกล้กับ a ("ใกล้กัน" เมื่อ |𝑎 − 𝑥^2 | ≤ 10^−10max (𝑎, 𝑥^2 ) )
# • ถ้า x2 > a ก็เปลี่ยนช่วงเป็น [L, x]
# • ถ้า x2 < a ก็เปลี่ยนช่วงเป็น [x, U]
# • x = จุดกึ่งกลางของช่วง
# 5. x คือค่าประมาณของ sqr a
# จงนำแนวคิดของ bisection ข้างต้นมาใช้หาค่าประมาณของ log10 a โดยที่ a >= 1

# %%
import math
a=float(input())
L=0
U=a
x=(U+L)/2
#while not math.isclose(a,x**2):
while (abs(a-x**2)>1e-10*max(a,x**2)):
    print('x=',x)
    if x**2>a:
        U=x
    else:
        L=x
    x=(U+L)/2

print(x)
# Out:
# 100
# x= 50.0
# x= 25.0
# x= 12.5
# x= 6.25
# x= 9.375
# x= 10.9375
# x= 10.15625
# x= 9.765625
# x= 9.9609375
# x= 10.05859375
# x= 10.009765625
# x= 9.9853515625
# x= 9.99755859375
# x= 10.003662109375
# x= 10.0006103515625
# x= 9.99908447265625
# x= 9.999847412109375
# x= 10.000228881835938
# x= 10.000038146972656
# x= 9.999942779541016
# x= 9.999990463256836
# x= 10.000014305114746
# x= 10.000002384185791
# x= 9.999996423721313
# x= 9.999999403953552
# x= 10.000000894069672
# x= 10.000000149011612
# x= 9.999999776482582
# x= 9.999999962747097
# x= 10.000000055879354
# x= 10.000000009313226
# x= 9.999999986030161
# x= 9.999999997671694
# x= 10.00000000349246
# x= 10.000000000582077
# x= 9.999999999126885
# 9.99999999985448

# %%
1# x = a**0.5
# x**2 = a
#ทำ inverse
#(a**0.5)**2 ==a
#อยากจะหาlog10(a)
#inverse
#10**log10(a)==a
import math
a=float(input())
L=0
U=a
x=(U+L)/2
while not math.isclose(a,10**x):
    #print('x=',x)
    if 10**x>a:
        U=x
    else:
        L=x
    x=(U+L)/2
#print("{:.6f}".format(x))
print(round(x,6))
# Out:
# 50
# 1.698970
# 1.69897

# %% [markdown]
# 04-05: การตรวจคำตอบปรนัย 💡
# จงเขียนโปรแกรมรับสตริง 2 ตัว สตริงแรกเป็นเฉลยคำตอบปรนัย อีกสตริงเป็นคำตอบของนักเรียน แล้วแสดงว่าถูกกี่ข้อ เช่น
#
# *   สตริงเฉลยคือ AAABC แทนเฉลย A, A, A, B และ C ของข้อที่ 1 ถึง 5 ตามลำดับ
# *   สตริงคำตอบคือ AABCC แทนคำตอบ A, A, B, C และ C ของข้อที่ 1 ถึง 5 ของนักเรียนคนนี้
# *  สรุปว่า นักเรียนคนนี้ตอบถูก 3 ข้อ
#
#
# ข้อมูลนำเข้า
# บรรทัดแรกเป็นสตริงเฉลย บรรทัดที่สองเป็นสตริงคำตอบ
# ข้อมูลส่งออก
# จำนวนคำตอบที่ถูกต้อง ถ้าจำนวนข้อของเฉลยไม่ตรงกับของคำตอบ ให้แสดง Incomplete answer

# %%
s = input() 
ans = input() 
sum=0
i=0
print(len(s),len(ans))
if len(s)!=len(ans):
    print('Incomplete answer')
else:
    for i in range (len(s)):
        if s[i]==ans[i]:
            sum+=1
print(sum)
# Out:
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAA
# 29 12
# Incomplete answer
# 0

# %% [markdown]
# 04-06: วงเล็บเปิดปิด
# จงเขียนโปรแกรมรับสตริง จากนั้นสร้างสตริงใหม่ที่
#
#
# *   แทน ( ด้วย [
# *   แทน [ ด้วย (
#
#
# *   แทน ) ด้วย ]
# *   แทน ] ด้วย )</br>
# แล้วแสดงผลทางจอภาพ
#
# input [[a + (b + [c / d] – e) + f] + 4]</br>
# output ((a + [b + (c / d) – e] + f) + 4)

# %%
s=input()
out = ''
for c in s:
    if c =='(':
        out+='['
    elif c=='[':
        out+='('
    elif c==')':
        out+=']'
    elif c==']':
        out+=')'
    else:
        out+=c 
print(out)
# Out:
# no parentheses
# no parentheses

# %% [markdown]
# 04-07: การนับจำนวนคำที่สนใจ </br>
# จงเขียนโปรแกรมที่รับคำที่สนใจ แล้วก็รับข้อความหนึ่งบรรทัด จากนั้นนับว่าในข้อความที่รับ มีจำนวนคำที่สนใจกี่คำ</br>
# หมายเหตุ: กำหนดให้คำที่สนใจมีแต่ตัวอักษรภาษาอังกฤษ และ ข้อความที่รับเข้ามาประกอบด้วยตัวอักษรภาษาอังกฤษ ตัวเลข หรือ</br>
# เครื่องหมายวรรคตอน " ( ) , . หรือ '
# ข้อ
#
# ข้อมูลนำเข้า</br>
# สตริง 2 บรรทัด บรรทัดแรกคือคำที่สนใจ บรรทัดที่สองคือข้อความ</br>
# ข้อมูลส่งออก</br>
# จำนวนคำที่สนใจในข้อความที่รับเข้ามา (ให้ถือว่าตัวอังกฤษใหญ่ไม่เหมือนตัวเล็ก)
#
# input</br>
# บรรทัดแรก the</br>
# บรรทัดที่ 2  The word "the" is one of the most common words in English.</br>
# output</br>
# 2

# %%
q=input()
s=input()
t =''
for c in s:
    if c in ['"','(',')',',','.',"'" ]:
        t+=' '
    else:
        t+=c
c=0
for w in t.split():
    if w==q:
        c+=1
print(c)
# Out:
# the
# The word "the" is one of the most common words in Englis
# 2

# %% [markdown]
# 04-08: การวาดสามเหลี่ยมสูง h 💡
# จงเขียนโปรแกรมรับจำนวนเต็มที่แทนความสูง h แล้ววาดสามเหลี่ยมหน้าจั่วความสูง h ฐานกว้าง 2h – 1
# ข้อมูลนำเข้า
# จำนวนเต็มหนึ่งจำนวนแทนความสูงสามเหลี่ยมหน้าจั่ว (ความสูง  2)
# ข้อมูลส่งออก
# สตริงจำนวนบรรทัดเท่ากับความสูงที่ได้รับ แทนรูปสามเหลี่ยมหน้าจั่ว ดังตัวอย่างข้างล่างนี้

# %% [markdown]
# ![tree.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![code.JPG](data:image/jpeg;base64,...)

# %%
h=int(input())
print('  '*(h-1)+'*')
i1=h-2
i2=1
for i in range (h-2):
    print('  '*i1+'*'+'  '*i2+'*')
    i1-=1
    i2+=2
print( '*' * (2*h-1))
# Out:
# 4
#       *
#     *  *
#   *      *
# *******

# %%
h=int(input())
print('  '*(h-1)+'*')
 
for i in range (h-2):
    print('  '*(h-2-i)+'*'+'  '*(2*i+1)+'*')
print( '*' * (2*h-1))
# Out:
# 8
#               *
#             *  *
#           *      *
#         *          *
#       *              *
#     *                  *
#   *                      *
# ***************

# %% [markdown]
# ![log10.JPG](data:image/jpeg;base64,...)

# %%
import math
a=float(input())
L=0
 
a0=a 
U=0
#U=a ประเมินค่า U ด้วย 1+log10 a 
#ให้ a //10 ไปเรื่อยๆ จนลงตัว จำนวนครั้งก็คือ 1+log10 a = U
while a0>0:
    a0//=10
    U+=1

x=(U+L)/2
while not math.isclose(a,10**x):
    #print('x=',x)
    if 10**x>a:
        U=x
    else:
        L=x
    x=(U+L)/2
#print("{:.6f}".format(x))
print(round(x,6))
# Out:
# 123456
# 5.091512

# %%
100a=float(input())
a0=a 
U=0
while a0>0:
    a0//=10
    U+=1

print(U)
# Out:
# 10
# 2

# %% [markdown]
# 04-11: Zig-Zag / Zag-Zig (แบบที่ 1)

# %% [markdown]
# ![4-11.JPG](data:image/jpeg;base64,...)

# %%
n=int(input())
c=0
red=[0]*n #สร้าง list รอ n ช่อง
blue=[0]*n
for i in range(n):
    x,y=(input().split())
    x=int(x)
    y=int(y)
    if i%2==0:
        red[i]=x
        blue[i]=y
    else:
        red[i]=y
        blue[i]=x
zz=input()
if zz =='Zig-Zag':
    print(min(red),max(blue))
else:
    print(min(blue),max(red))
# Out:
# 3
# -10 10
# 20 -20
# -30 30
# Zig-Zag
# -30 30

# %%
n=int(input())
red=[0]*n #สร้าง list รอ n ช่อง
blue=[0]*n
for i in range(n):
    x,y=(input().split())
    x=int(x)
    y=int(y)
    if i%2==1:#คี่สลับ
        x,y=y,x
    red[i]=x
    blue[i]=y
zz=input()
if zz =='Zig-Zag':
    print(min(red),max(blue))
else:
    print(min(blue),max(red))
# Out:
# 3
# -10 10
# 20 -20
# -30 30
# Zig-Zag
# -30 30

# %%
n=int(input())
red=[0]*n #สร้าง list รอ n ช่อง
blue=[0]*n
for i in range(n):
    x,y=(input().split())
    x=int(x)
    y=int(y)
    if i%2==1:#คี่สลับ
        x,y=y,x
    red[i]=x
    blue[i]=y
zz=input()
if zz =='Zag-Zig':
    red,blue=blue,red
print(min(red),max(blue))
# Out:
# 3
# -10 10
# 20 -20
# -30 30
# Zig-Zag
# -30 30

# %% [markdown]
# 04-12: Zig-Zag / Zag-Zig (แบบที่ 2) แบบไม่ใช่ list

# %% [markdown]
# ![4-12.JPG](data:image/jpeg;base64,...)

# %%
x,y=(input().split())
x,y=int(x),int(y)
min_zigzag = x
max_zigzag = y
min_zagzig = y
max_zagzig = x
i=1 #เริ่มแถวที่ 1 เพราะค่าแรกคือแถวที่ 0 แถวที่ 1 จะเริ่มด้วย max x2, min y2
while True:
    d=input().split()
    if len(d)==1:break  #ถ้าพิมพ์ Zig-Zag หรือ Zag-Zig ข้อมูลจะเหลือค่าเดียว
    x,y=int(d[0]),int(d[1])
    if i%2==1:#คี่สลับ
        x,y=y,x
    min_zigzag =min(min_zigzag,x)
    max_zigzag =max(max_zigzag,y)

    min_zagzig =min(min_zagzig,y)
    max_zagzig =max(max_zagzig,x)

    i+=1

zz=d[0]
if zz=='Zig-Zag':
    print(min_zigzag,max_zigzag)
else:
    print(min_zagzig,max_zagzig)
# Out:
# -10 10
# 20 -20
# -30 30
# Zig-Zag
# -30 30

# %%
-10 10
20 -20
-30 30
Zig-Zag


-30 30
